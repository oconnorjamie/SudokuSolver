# %%
import threading
import tkinter as tk
from tkinter import ttk
import numpy as np
import random
import math
import matplotlib.pyplot as plt
import statistics
import time

# Enter any board you'd like here in string format:
sudokuorg = """
100000000
000600000
060935000
002340060
300001002
000000084
050060000
001002090
800000071
"""

class MyApp:
    def __init__(self, root):
        self.root = root
        self.root.title("9x9 Grid of Buttons")
        
        self.buttons = []
        self.create_grid()
    
    def create_grid(self):
        for i in range(9):
            row = []
            for j in range(9):
                button = tk.Button(self.root, text="", width=4, height=2, command=lambda i=i, j=j: self.on_button_click(i, j))
                button.grid(row=i, column=j, padx=5, pady=5, sticky="nsew")
                row.append(button)
            self.buttons.append(row)
                
        for i in range(9):
            self.root.grid_rowconfigure(i, weight=1)
            self.root.grid_columnconfigure(i, weight=1)
    
    def on_button_click(self, i, j):
        print(f"Button {i},{j} clicked")
    
    def update_grid(self, data, cost):
        lines = data.strip().split("\n")
        max_cost = 50  # Define the maximum cost for red color
        for i in range(9):
            for j in range(9):
                self.buttons[i][j].config(text=lines[i][j])
                if cost > 8:
                    color = "#000000"  #Black
                elif cost > 6:
                    color = "#8B0000"  # dark red
                elif cost > 4:
                    color = "#FF0000"  # red
                elif cost > 2:
                    color = "#FF4500"  # orange
                elif cost > 0:
                    color = "#ffff00"  # yello
                elif cost==0:
                    color = "#008000"  # Green
                self.buttons[i][j].config(bg=color)

def start_tkinter_app():
    global app
    root = tk.Tk()
    root.geometry("600x600")
    root.lift()
    root.attributes("-topmost", True)
    root.attributes("-topmost", False)
    app = MyApp(root)
    root.mainloop()

gui_thread = threading.Thread(target=start_tkinter_app)
gui_thread.start()

def initialStateGen(sudoku_str):
    def get_subgrid_indices(subgrid_number):
        row_start = (subgrid_number // 3) * 3
        col_start = (subgrid_number % 3) * 3
        indices = [(row_start + i) * 9 + (col_start + j) for i in range(3) for j in range(3)]
        return indices

    sudoku = list(sudoku_str.replace('\n', ''))
    
    def fill_subgrid(sudoku, subgrid_number):
        indices = get_subgrid_indices(subgrid_number)
        numbers_present = {int(sudoku[index]) for index in indices if sudoku[index] != '0'}
        missing_numbers = list(set(range(1, 10)) - numbers_present)
        random.shuffle(missing_numbers)
        
        for index in indices:
            if sudoku[index] == '0':
                sudoku[index] = str(missing_numbers.pop())
    
    for subgrid_number in range(9):
        fill_subgrid(sudoku, subgrid_number)
    
    result = ''.join(sudoku)
    return '\n'.join([result[i:i+9] for i in range(0, 81, 9)])

def fixSudokuValues(sudoku_str):
    fixed_sudoku = list(sudoku_str.replace('\n', ''))
    for i in range(len(fixed_sudoku)):
        if fixed_sudoku[i] != '0':
            fixed_sudoku[i] = '1'
        else:
            fixed_sudoku[i] = '0'
    return ''.join(fixed_sudoku)

def nextGen(sudoku_str, fixed_sudoku_str):
    def get_subgrid_indices(subgrid_number):
        row_start = (subgrid_number // 3) * 3
        col_start = (subgrid_number % 3) * 3
        indices = [(row_start + i) * 9 + (col_start + j) for i in range(3) for j in range(3)]
        return indices
    
    sudoku = list(sudoku_str.replace('\n', ''))
    fixed_sudoku = list(fixed_sudoku_str.replace('\n', ''))
    subgrid_number = random.randint(0, 8)
    indices = get_subgrid_indices(subgrid_number)
    
    non_fixed_indices = [idx for idx in indices if fixed_sudoku[idx] == '0']
    
    if len(non_fixed_indices) < 2:
        return '\n'.join([sudoku_str[i:i+9] for i in range(0, 81, 9)])
    
    idx1, idx2 = random.sample(non_fixed_indices, 2)
    sudoku[idx1], sudoku[idx2] = sudoku[idx2], sudoku[idx1]
    
    result = ''.join(sudoku)
    return '\n'.join([result[i:i+9] for i in range(0, 81, 9)])

def calculatingCost(board):
    board = board.replace('\n', '')
    total = 0
    
    for i in range(9):
        row_count = [0] * 10
        col_count = [0] * 10
        for j in range(9):
            row_num = int(board[i * 9 + j])
            col_num = int(board[j * 9 + i])
            if row_num != 0:
                row_count[row_num] += 1
            if col_num != 0:
                col_count[col_num] += 1
        
        total += sum(x - 1 for x in row_count if x > 1)
        total += sum(x - 1 for x in col_count if x > 1)
    
    return total

def simulatedAnnealing(sudoku_str, initial_temp, cooling_rate, max_iterations):
    current_sudoku = initialStateGen(sudoku_str)
    fixed_sudoku = fixSudokuValues(sudoku_str)
    current_cost = calculatingCost(current_sudoku)
    temperature = initial_temp
    
    best_sudoku = current_sudoku
    best_cost = current_cost

    costs = [current_cost]
    iteration = 0
    stuck_count = 0

    while current_cost != 0 and iteration < max_iterations:
        new_sudoku = nextGen(current_sudoku, fixed_sudoku)
        new_cost = calculatingCost(new_sudoku)
        
        cost_diff = new_cost - current_cost
        acceptance_probability = math.exp(-cost_diff / temperature) if cost_diff > 0 else 1

        if random.random() < acceptance_probability:
            current_sudoku = new_sudoku
            current_cost = new_cost

        if current_cost < best_cost:
            best_sudoku = current_sudoku
            best_cost = current_cost
        
        temperature *= cooling_rate
        costs.append(current_cost)
        iteration += 1

        if current_cost >= best_cost:
            stuck_count += 1
        else:
            stuck_count = 0

        if stuck_count > 10000:
            temperature *= 1.1
            stuck_count = 0
            if temperature < 0.01:
                temperature += 3.5
                max_iterations *= 1.1

        # Update GUI every 1000 iterations
        if iteration % 1000 == 0:
            app.update_grid(current_sudoku, current_cost)
            print(f"Iteration {iteration}, Current Cost: {current_cost}")
    app.update_grid(current_sudoku, current_cost)
    return best_sudoku, best_cost, costs

# Parameters for the simulated annealing
initial_temp = 3.5  # Increased initial temperature
cooling_rate = 0.99  # Slower cooling rate
max_iterations = 100000  # Increased number of iterations

# Wait a bit for the GUI to be ready
time.sleep(1)

# Update the GUI inside the annealing function
best_sudoku, best_cost, costs = simulatedAnnealing(sudokuorg, initial_temp, cooling_rate, max_iterations)

print("Best Sudoku State:\n\n", best_sudoku)
print("\nBest Cost:", best_cost)

# Plotting the cost reduction over iterations
plt.plot(costs)
plt.xlabel('Iteration')
plt.ylabel('Cost')
plt.title('Cost Reduction Over Iterations')
plt.show()
# Out:
# Iteration 1000, Current Cost: 4
# Iteration 2000, Current Cost: 4
# Iteration 3000, Current Cost: 4
# Iteration 4000, Current Cost: 4
# Iteration 5000, Current Cost: 4
# Iteration 6000, Current Cost: 4
# Iteration 7000, Current Cost: 4
# Iteration 8000, Current Cost: 4
# Iteration 9000, Current Cost: 4
# Iteration 10000, Current Cost: 4
# Iteration 11000, Current Cost: 9
# Iteration 12000, Current Cost: 5
# Iteration 13000, Current Cost: 5
# Iteration 14000, Current Cost: 5
# Iteration 15000, Current Cost: 5
# Iteration 16000, Current Cost: 5
# Iteration 17000, Current Cost: 5
# Iteration 18000, Current Cost: 5
# Iteration 19000, Current Cost: 5
# Iteration 20000, Current Cost: 5
# Iteration 21000, Current Cost: 7
# Iteration 22000, Current Cost: 4
# Iteration 23000, Current Cost: 4
# Iteration 24000, Current Cost: 4
# Iteration 25000, Current Cost: 4
# Iteration 26000, Current Cost: 4
# Iteration 27000, Current Cost: 4
# Iteration 28000, Current Cost: 4
# Iteration 29000, Current Cost: 4
# Iteration 30000, Current Cost: 4
# Iteration 31000, Current Cost: 8
# Iteration 32000, Current Cost: 6
# Iteration 33000, Current Cost: 6
# Iteration 34000, Current Cost: 6
# Iteration 35000, Current Cost: 5
# Iteration 36000, Current Cost: 4
# Iteration 37000, Current Cost: 4
# Iteration 38000, Current Cost: 2
# Iteration 39000, Current Cost: 2
# Iteration 40000, Current Cost: 2
# Iteration 41000, Current Cost: 10
# Iteration 42000, Current Cost: 7
# Iteration 43000, Current Cost: 4
# Iteration 44000, Current Cost: 2
# Iteration 45000, Current Cost: 2
# Iteration 46000, Current Cost: 2
# Iteration 47000, Current Cost: 2
# Iteration 48000, Current Cost: 2
# Iteration 49000, Current Cost: 2
# Iteration 50000, Current Cost: 2
# Iteration 51000, Current Cost: 12
# Iteration 52000, Current Cost: 8
# Iteration 53000, Current Cost: 6
# Iteration 54000, Current Cost: 6
# Iteration 55000, Current Cost: 6
# Iteration 56000, Current Cost: 6
# Iteration 57000, Current Cost: 6
# Iteration 58000, Current Cost: 6
# Iteration 59000, Current Cost: 6
# Iteration 60000, Current Cost: 6
# Iteration 61000, Current Cost: 9
# Iteration 62000, Current Cost: 7
# Iteration 63000, Current Cost: 6
# Iteration 64000, Current Cost: 6
# Iteration 65000, Current Cost: 4
# Iteration 66000, Current Cost: 4
# Iteration 67000, Current Cost: 4
# Iteration 68000, Current Cost: 4
# Iteration 69000, Current Cost: 4
# Iteration 70000, Current Cost: 4
# Iteration 71000, Current Cost: 11
# Iteration 72000, Current Cost: 9
# Iteration 73000, Current Cost: 9
# Iteration 74000, Current Cost: 8
# Iteration 75000, Current Cost: 8
# Iteration 76000, Current Cost: 8
# Iteration 77000, Current Cost: 8
# Iteration 78000, Current Cost: 8
# Iteration 79000, Current Cost: 8
# Iteration 80000, Current Cost: 8
# Iteration 81000, Current Cost: 8
# Iteration 82000, Current Cost: 6
# Iteration 83000, Current Cost: 6
# Iteration 84000, Current Cost: 6
# Iteration 85000, Current Cost: 6
# Iteration 86000, Current Cost: 4
# Iteration 87000, Current Cost: 4
# Iteration 88000, Current Cost: 4
# Iteration 89000, Current Cost: 4
# Iteration 90000, Current Cost: 4
# Iteration 91000, Current Cost: 11
# Iteration 92000, Current Cost: 10
# Iteration 93000, Current Cost: 4
# Iteration 94000, Current Cost: 4
# Iteration 95000, Current Cost: 4
# Iteration 96000, Current Cost: 4
# Iteration 97000, Current Cost: 4
# Iteration 98000, Current Cost: 4
# Iteration 99000, Current Cost: 4
# Iteration 100000, Current Cost: 4
# Iteration 101000, Current Cost: 9
# Iteration 102000, Current Cost: 4
# Iteration 103000, Current Cost: 4
# Iteration 104000, Current Cost: 4
# Iteration 105000, Current Cost: 4
# Iteration 106000, Current Cost: 4
# Iteration 107000, Current Cost: 4
# Iteration 108000, Current Cost: 4
# Iteration 109000, Current Cost: 4
# Iteration 110000, Current Cost: 4
# Iteration 111000, Current Cost: 8
# Iteration 112000, Current Cost: 7
# Iteration 113000, Current Cost: 5
# Iteration 114000, Current Cost: 2
# Iteration 115000, Current Cost: 2
# Iteration 116000, Current Cost: 2
# Iteration 117000, Current Cost: 2
# Iteration 118000, Current Cost: 2
# Iteration 119000, Current Cost: 2
# Iteration 120000, Current Cost: 2
# Iteration 121000, Current Cost: 8
# Iteration 122000, Current Cost: 6
# Iteration 123000, Current Cost: 6
# Iteration 124000, Current Cost: 6
# Iteration 125000, Current Cost: 6
# Iteration 126000, Current Cost: 6
# Iteration 127000, Current Cost: 6
# Iteration 128000, Current Cost: 6
# Iteration 129000, Current Cost: 6
# Iteration 130000, Current Cost: 6
# Iteration 131000, Current Cost: 6
# Iteration 132000, Current Cost: 5
# Iteration 133000, Current Cost: 5
# Iteration 134000, Current Cost: 5
# Iteration 135000, Current Cost: 5
# Iteration 136000, Current Cost: 5
# Iteration 137000, Current Cost: 5
# Iteration 138000, Current Cost: 5
# Iteration 139000, Current Cost: 5
# Iteration 140000, Current Cost: 5
# Iteration 141000, Current Cost: 8
# Iteration 142000, Current Cost: 8
# Iteration 143000, Current Cost: 8
# Iteration 144000, Current Cost: 4
# Iteration 145000, Current Cost: 4
# Iteration 146000, Current Cost: 4
# Iteration 147000, Current Cost: 4
# Iteration 148000, Current Cost: 4
# Iteration 149000, Current Cost: 4
# Iteration 150000, Current Cost: 4
# Iteration 151000, Current Cost: 8
# Iteration 152000, Current Cost: 6
# Iteration 153000, Current Cost: 2
# Iteration 154000, Current Cost: 2
# Iteration 155000, Current Cost: 2
# Iteration 156000, Current Cost: 2
# Iteration 157000, Current Cost: 2
# Iteration 158000, Current Cost: 2
# Iteration 159000, Current Cost: 2
# Iteration 160000, Current Cost: 2
# Iteration 161000, Current Cost: 7
# Iteration 162000, Current Cost: 6
# Iteration 163000, Current Cost: 6
# Iteration 164000, Current Cost: 2
# Iteration 165000, Current Cost: 2
# Iteration 166000, Current Cost: 2
# Iteration 167000, Current Cost: 2
# Iteration 168000, Current Cost: 2
# Iteration 169000, Current Cost: 2
# Iteration 170000, Current Cost: 2
# Iteration 171000, Current Cost: 8
# Iteration 172000, Current Cost: 4
# Iteration 173000, Current Cost: 4
# Iteration 174000, Current Cost: 4
# Iteration 175000, Current Cost: 4
# Iteration 176000, Current Cost: 4
# Iteration 177000, Current Cost: 4
# Iteration 178000, Current Cost: 4
# Iteration 179000, Current Cost: 4
# Iteration 180000, Current Cost: 4
# Iteration 181000, Current Cost: 11
# Iteration 182000, Current Cost: 9
# Iteration 183000, Current Cost: 7
# Iteration 184000, Current Cost: 7
# Iteration 185000, Current Cost: 7
# Iteration 186000, Current Cost: 7
# Iteration 187000, Current Cost: 7
# Iteration 188000, Current Cost: 7
# Iteration 189000, Current Cost: 7
# Iteration 190000, Current Cost: 7
# Iteration 191000, Current Cost: 4
# Iteration 192000, Current Cost: 4
# Iteration 193000, Current Cost: 4
# Iteration 194000, Current Cost: 4
# Iteration 195000, Current Cost: 4
# Iteration 196000, Current Cost: 4
# Iteration 197000, Current Cost: 4
# Iteration 198000, Current Cost: 4
# Iteration 199000, Current Cost: 4
# Iteration 200000, Current Cost: 3
# Iteration 201000, Current Cost: 10
# Iteration 202000, Current Cost: 6
# Iteration 203000, Current Cost: 4
# Iteration 204000, Current Cost: 4
# Iteration 205000, Current Cost: 3
# Iteration 206000, Current Cost: 3
# Iteration 207000, Current Cost: 3
# Iteration 208000, Current Cost: 3
# Iteration 209000, Current Cost: 3
# Iteration 210000, Current Cost: 3
# Iteration 211000, Current Cost: 7
# Iteration 212000, Current Cost: 7
# Iteration 213000, Current Cost: 5
# Iteration 214000, Current Cost: 5
# Iteration 215000, Current Cost: 4
# Iteration 216000, Current Cost: 3
# Iteration 217000, Current Cost: 3
# Iteration 218000, Current Cost: 3
# Iteration 219000, Current Cost: 3
# Iteration 220000, Current Cost: 3
# Iteration 221000, Current Cost: 6
# Iteration 222000, Current Cost: 4
# Iteration 223000, Current Cost: 4
# Iteration 224000, Current Cost: 4
# Iteration 225000, Current Cost: 4
# Iteration 226000, Current Cost: 4
# Iteration 227000, Current Cost: 4
# Iteration 228000, Current Cost: 4
# Iteration 229000, Current Cost: 4
# Iteration 230000, Current Cost: 4
# Iteration 231000, Current Cost: 6
# Iteration 232000, Current Cost: 5
# Iteration 233000, Current Cost: 4
# Iteration 234000, Current Cost: 4
# Iteration 235000, Current Cost: 4
# Iteration 236000, Current Cost: 4
# Iteration 237000, Current Cost: 4
# Iteration 238000, Current Cost: 4
# Iteration 239000, Current Cost: 4
# Iteration 240000, Current Cost: 4
# Iteration 241000, Current Cost: 10
# Iteration 242000, Current Cost: 9
# Iteration 243000, Current Cost: 6
# Iteration 244000, Current Cost: 6
# Iteration 245000, Current Cost: 6
# Iteration 246000, Current Cost: 6
# Iteration 247000, Current Cost: 6
# Iteration 248000, Current Cost: 6
# Iteration 249000, Current Cost: 6
# Iteration 250000, Current Cost: 6
# Iteration 251000, Current Cost: 8
# Iteration 252000, Current Cost: 6
# Iteration 253000, Current Cost: 6
# Iteration 254000, Current Cost: 6
# Iteration 255000, Current Cost: 6
# Iteration 256000, Current Cost: 6
# Iteration 257000, Current Cost: 6
# Iteration 258000, Current Cost: 6
# Iteration 259000, Current Cost: 6
# Iteration 260000, Current Cost: 6
# Iteration 261000, Current Cost: 11
# Iteration 262000, Current Cost: 8
# Iteration 263000, Current Cost: 6
# Iteration 264000, Current Cost: 5
# Iteration 265000, Current Cost: 4
# Iteration 266000, Current Cost: 4
# Iteration 267000, Current Cost: 4
# Iteration 268000, Current Cost: 4
# Iteration 269000, Current Cost: 4
# Iteration 270000, Current Cost: 4
# Iteration 271000, Current Cost: 6
# Iteration 272000, Current Cost: 4
# Iteration 273000, Current Cost: 4
# Iteration 274000, Current Cost: 4
# Iteration 275000, Current Cost: 4
# Iteration 276000, Current Cost: 4
# Iteration 277000, Current Cost: 4
# Iteration 278000, Current Cost: 4
# Iteration 279000, Current Cost: 4
# Iteration 280000, Current Cost: 4
# Iteration 281000, Current Cost: 8
# Iteration 282000, Current Cost: 6
# Iteration 283000, Current Cost: 2
# Iteration 284000, Current Cost: 2
# Iteration 285000, Current Cost: 2
# Iteration 286000, Current Cost: 2
# Iteration 287000, Current Cost: 2
# Iteration 288000, Current Cost: 2
# Iteration 289000, Current Cost: 2
# Iteration 290000, Current Cost: 2
# Iteration 291000, Current Cost: 7
# Iteration 292000, Current Cost: 3
# Iteration 293000, Current Cost: 2
# Iteration 294000, Current Cost: 2
# Iteration 295000, Current Cost: 2
# Iteration 296000, Current Cost: 2
# Iteration 297000, Current Cost: 2
# Iteration 298000, Current Cost: 2
# Iteration 299000, Current Cost: 2
# Iteration 300000, Current Cost: 2
# Iteration 301000, Current Cost: 8
# Iteration 302000, Current Cost: 6
# Iteration 303000, Current Cost: 4
# Iteration 304000, Current Cost: 4
# Iteration 305000, Current Cost: 4
# Iteration 306000, Current Cost: 4
# Iteration 307000, Current Cost: 4
# Iteration 308000, Current Cost: 4
# Iteration 309000, Current Cost: 4
# Iteration 310000, Current Cost: 4
# Iteration 311000, Current Cost: 11
# Iteration 312000, Current Cost: 9
# Iteration 313000, Current Cost: 9
# Iteration 314000, Current Cost: 8
# Iteration 315000, Current Cost: 6
# Iteration 316000, Current Cost: 6
# Iteration 317000, Current Cost: 6
# Iteration 318000, Current Cost: 6
# Iteration 319000, Current Cost: 6
# Iteration 320000, Current Cost: 6
# Iteration 321000, Current Cost: 10
# Iteration 322000, Current Cost: 8
# Iteration 323000, Current Cost: 6
# Iteration 324000, Current Cost: 4
# Iteration 325000, Current Cost: 4
# Iteration 326000, Current Cost: 4
# Iteration 327000, Current Cost: 4
# Iteration 328000, Current Cost: 4
# Iteration 329000, Current Cost: 4
# Iteration 330000, Current Cost: 4
# Iteration 331000, Current Cost: 12
# Iteration 332000, Current Cost: 10
# Iteration 333000, Current Cost: 10
# Iteration 334000, Current Cost: 8
# Iteration 335000, Current Cost: 6
# Iteration 336000, Current Cost: 6
# Iteration 337000, Current Cost: 6
# Iteration 338000, Current Cost: 6
# Iteration 339000, Current Cost: 5
# Iteration 340000, Current Cost: 5
# Iteration 341000, Current Cost: 7
# Iteration 342000, Current Cost: 2
# Iteration 343000, Current Cost: 2
# Iteration 344000, Current Cost: 2
# Iteration 345000, Current Cost: 2
# Iteration 346000, Current Cost: 2
# Iteration 347000, Current Cost: 2
# Iteration 348000, Current Cost: 2
# Iteration 349000, Current Cost: 2
# Iteration 350000, Current Cost: 2
# Iteration 351000, Current Cost: 4
# Iteration 352000, Current Cost: 4
# Iteration 353000, Current Cost: 4
# Iteration 354000, Current Cost: 2
# Iteration 355000, Current Cost: 2
# Iteration 356000, Current Cost: 2
# Iteration 357000, Current Cost: 2
# Iteration 358000, Current Cost: 2
# Iteration 359000, Current Cost: 2
# Iteration 360000, Current Cost: 2
# Iteration 361000, Current Cost: 10
# Iteration 362000, Current Cost: 8
# Iteration 363000, Current Cost: 5
# Iteration 364000, Current Cost: 4
# Iteration 365000, Current Cost: 4
# Iteration 366000, Current Cost: 4
# Iteration 367000, Current Cost: 4
# Iteration 368000, Current Cost: 4
# Iteration 369000, Current Cost: 2
# Iteration 370000, Current Cost: 2
# Iteration 371000, Current Cost: 7
# Iteration 372000, Current Cost: 4
# Iteration 373000, Current Cost: 4
# Iteration 374000, Current Cost: 4
# Iteration 375000, Current Cost: 4
# Iteration 376000, Current Cost: 4
# Iteration 377000, Current Cost: 4
# Iteration 378000, Current Cost: 4
# Iteration 379000, Current Cost: 4
# Iteration 380000, Current Cost: 4
# Iteration 381000, Current Cost: 7
# Iteration 382000, Current Cost: 2
# Iteration 383000, Current Cost: 2
# Iteration 384000, Current Cost: 2
# Iteration 385000, Current Cost: 2
# Iteration 386000, Current Cost: 2
# Iteration 387000, Current Cost: 2
# Iteration 388000, Current Cost: 2
# Iteration 389000, Current Cost: 2
# Iteration 390000, Current Cost: 2
# Iteration 391000, Current Cost: 6
# Iteration 392000, Current Cost: 2
# Iteration 393000, Current Cost: 2
# Iteration 394000, Current Cost: 2
# Iteration 395000, Current Cost: 2
# Iteration 396000, Current Cost: 2
# Iteration 397000, Current Cost: 2
# Iteration 398000, Current Cost: 2
# Iteration 399000, Current Cost: 2
# Iteration 400000, Current Cost: 2
# Iteration 401000, Current Cost: 12
# Iteration 402000, Current Cost: 6
# Iteration 403000, Current Cost: 6
# Iteration 404000, Current Cost: 6
# Iteration 405000, Current Cost: 6
# Iteration 406000, Current Cost: 6
# Iteration 407000, Current Cost: 6
# Iteration 408000, Current Cost: 6
# Iteration 409000, Current Cost: 2
# Iteration 410000, Current Cost: 2
# Iteration 411000, Current Cost: 9
# Iteration 412000, Current Cost: 7
# Iteration 413000, Current Cost: 7
# Iteration 414000, Current Cost: 6
# Iteration 415000, Current Cost: 3
# Iteration 416000, Current Cost: 3
# Iteration 417000, Current Cost: 3
# Iteration 418000, Current Cost: 3
# Iteration 419000, Current Cost: 3
# Iteration 420000, Current Cost: 3
# Iteration 421000, Current Cost: 13
# Iteration 422000, Current Cost: 8
# Iteration 423000, Current Cost: 6
# Iteration 424000, Current Cost: 4
# Iteration 425000, Current Cost: 4
# Iteration 426000, Current Cost: 4
# Iteration 427000, Current Cost: 4
# Iteration 428000, Current Cost: 4
# Iteration 429000, Current Cost: 4
# Iteration 430000, Current Cost: 4
# Iteration 431000, Current Cost: 11
# Iteration 432000, Current Cost: 8
# Iteration 433000, Current Cost: 5
# Iteration 434000, Current Cost: 5
# Iteration 435000, Current Cost: 5
# Iteration 436000, Current Cost: 5
# Iteration 437000, Current Cost: 5
# Iteration 438000, Current Cost: 5
# Iteration 439000, Current Cost: 5
# Iteration 440000, Current Cost: 5
# Iteration 441000, Current Cost: 9
# Iteration 442000, Current Cost: 8
# Iteration 443000, Current Cost: 4
# Iteration 444000, Current Cost: 2
# Iteration 445000, Current Cost: 2
# Iteration 446000, Current Cost: 2
# Iteration 447000, Current Cost: 2
# Iteration 448000, Current Cost: 2
# Iteration 449000, Current Cost: 2
# Iteration 450000, Current Cost: 2
# Iteration 451000, Current Cost: 5
# Iteration 452000, Current Cost: 2
# Iteration 453000, Current Cost: 2
# Iteration 454000, Current Cost: 2
# Iteration 455000, Current Cost: 2
# Iteration 456000, Current Cost: 2
# Iteration 457000, Current Cost: 2
# Iteration 458000, Current Cost: 2
# Iteration 459000, Current Cost: 2
# Iteration 460000, Current Cost: 2
# Iteration 461000, Current Cost: 8
# Iteration 462000, Current Cost: 6
# Iteration 463000, Current Cost: 6
# Iteration 464000, Current Cost: 4
# Iteration 465000, Current Cost: 4
# Iteration 466000, Current Cost: 4
# Iteration 467000, Current Cost: 4
# Iteration 468000, Current Cost: 4
# Iteration 469000, Current Cost: 4
# Iteration 470000, Current Cost: 4
# Iteration 471000, Current Cost: 10
# Iteration 472000, Current Cost: 6
# Iteration 473000, Current Cost: 5
# Iteration 474000, Current Cost: 5
# Iteration 475000, Current Cost: 5
# Iteration 476000, Current Cost: 5
# Iteration 477000, Current Cost: 4
# Iteration 478000, Current Cost: 4
# Iteration 479000, Current Cost: 4
# Iteration 480000, Current Cost: 4
# Iteration 481000, Current Cost: 8
# Iteration 482000, Current Cost: 6
# Iteration 483000, Current Cost: 4
# Iteration 484000, Current Cost: 4
# Iteration 485000, Current Cost: 2
# Iteration 486000, Current Cost: 2
# Iteration 487000, Current Cost: 2
# Iteration 488000, Current Cost: 2
# Iteration 489000, Current Cost: 2
# Iteration 490000, Current Cost: 2
# Iteration 491000, Current Cost: 6
# Iteration 492000, Current Cost: 4
# Iteration 493000, Current Cost: 4
# Iteration 494000, Current Cost: 4
# Iteration 495000, Current Cost: 4
# Iteration 496000, Current Cost: 4
# Iteration 497000, Current Cost: 4
# Iteration 498000, Current Cost: 4
# Iteration 499000, Current Cost: 2
# Iteration 500000, Current Cost: 2
# Iteration 501000, Current Cost: 7
# Iteration 502000, Current Cost: 7
# Iteration 503000, Current Cost: 7
# Iteration 504000, Current Cost: 7
# Iteration 505000, Current Cost: 6
# Iteration 506000, Current Cost: 4
# Iteration 507000, Current Cost: 4
# Iteration 508000, Current Cost: 4
# Iteration 509000, Current Cost: 2
# Iteration 510000, Current Cost: 2
# Iteration 511000, Current Cost: 9
# Iteration 512000, Current Cost: 4
# Iteration 513000, Current Cost: 4
# Iteration 514000, Current Cost: 4
# Iteration 515000, Current Cost: 4
# Iteration 516000, Current Cost: 4
# Iteration 517000, Current Cost: 4
# Iteration 518000, Current Cost: 4
# Iteration 519000, Current Cost: 4
# Iteration 520000, Current Cost: 4
# Iteration 521000, Current Cost: 6
# Iteration 522000, Current Cost: 4
# Iteration 523000, Current Cost: 4
# Iteration 524000, Current Cost: 4
# Iteration 525000, Current Cost: 4
# Iteration 526000, Current Cost: 3
# Iteration 527000, Current Cost: 2
# Iteration 528000, Current Cost: 2
# Iteration 529000, Current Cost: 2
# Iteration 530000, Current Cost: 2
# Iteration 531000, Current Cost: 9
# Iteration 532000, Current Cost: 6
# Iteration 533000, Current Cost: 5
# Iteration 534000, Current Cost: 5
# Iteration 535000, Current Cost: 5
# Iteration 536000, Current Cost: 4
# Iteration 537000, Current Cost: 4
# Iteration 538000, Current Cost: 4
# Iteration 539000, Current Cost: 4
# Iteration 540000, Current Cost: 4
# Iteration 541000, Current Cost: 5
# Iteration 542000, Current Cost: 4
# Iteration 543000, Current Cost: 2
# Iteration 544000, Current Cost: 2
# Iteration 545000, Current Cost: 2
# Iteration 546000, Current Cost: 2
# Iteration 547000, Current Cost: 2
# Iteration 548000, Current Cost: 2
# Iteration 549000, Current Cost: 2
# Iteration 550000, Current Cost: 2
# Iteration 551000, Current Cost: 7
# Iteration 552000, Current Cost: 4
# Iteration 553000, Current Cost: 4
# Iteration 554000, Current Cost: 4
# Iteration 555000, Current Cost: 4
# Iteration 556000, Current Cost: 4
# Iteration 557000, Current Cost: 4
# Iteration 558000, Current Cost: 4
# Iteration 559000, Current Cost: 2
# Iteration 560000, Current Cost: 2
# Iteration 561000, Current Cost: 7
# Iteration 562000, Current Cost: 6
# Iteration 563000, Current Cost: 4
# Iteration 564000, Current Cost: 2
# Iteration 565000, Current Cost: 2
# Iteration 566000, Current Cost: 2
# Iteration 567000, Current Cost: 2
# Iteration 568000, Current Cost: 2
# Iteration 569000, Current Cost: 2
# Iteration 570000, Current Cost: 2
# Iteration 571000, Current Cost: 6
# Iteration 572000, Current Cost: 6
# Iteration 573000, Current Cost: 6
# Iteration 574000, Current Cost: 6
# Iteration 575000, Current Cost: 6
# Iteration 576000, Current Cost: 6
# Iteration 577000, Current Cost: 6
# Iteration 578000, Current Cost: 6
# Iteration 579000, Current Cost: 6
# Iteration 580000, Current Cost: 6
# Iteration 581000, Current Cost: 5
# Iteration 582000, Current Cost: 2
# Iteration 583000, Current Cost: 2
# Iteration 584000, Current Cost: 2
# Iteration 585000, Current Cost: 2
# Iteration 586000, Current Cost: 2
# Iteration 587000, Current Cost: 2
# Iteration 588000, Current Cost: 2
# Iteration 589000, Current Cost: 2
# Iteration 590000, Current Cost: 2
# Iteration 591000, Current Cost: 10
# Iteration 592000, Current Cost: 6
# Iteration 593000, Current Cost: 6
# Iteration 594000, Current Cost: 6
# Iteration 595000, Current Cost: 6
# Iteration 596000, Current Cost: 4
# Iteration 597000, Current Cost: 4
# Iteration 598000, Current Cost: 4
# Iteration 599000, Current Cost: 4
# Iteration 600000, Current Cost: 4
# Iteration 601000, Current Cost: 11
# Iteration 602000, Current Cost: 9
# Iteration 603000, Current Cost: 9
# Iteration 604000, Current Cost: 4
# Iteration 605000, Current Cost: 4
# Iteration 606000, Current Cost: 4
# Iteration 607000, Current Cost: 4
# Iteration 608000, Current Cost: 4
# Iteration 609000, Current Cost: 4
# Iteration 610000, Current Cost: 4
# Iteration 611000, Current Cost: 12
# Iteration 612000, Current Cost: 5
# Iteration 613000, Current Cost: 5
# Iteration 614000, Current Cost: 4
# Iteration 615000, Current Cost: 4
# Iteration 616000, Current Cost: 4
# Iteration 617000, Current Cost: 4
# Iteration 618000, Current Cost: 4
# Iteration 619000, Current Cost: 4
# Iteration 620000, Current Cost: 4
# Iteration 621000, Current Cost: 11
# Iteration 622000, Current Cost: 2
# Iteration 623000, Current Cost: 2
# Iteration 624000, Current Cost: 2
# Iteration 625000, Current Cost: 2
# Iteration 626000, Current Cost: 2
# Iteration 627000, Current Cost: 2
# Iteration 628000, Current Cost: 2
# Iteration 629000, Current Cost: 2
# Iteration 630000, Current Cost: 2
# Iteration 631000, Current Cost: 9
# Iteration 632000, Current Cost: 4
# Iteration 633000, Current Cost: 2
# Iteration 634000, Current Cost: 2
# Iteration 635000, Current Cost: 2
# Iteration 636000, Current Cost: 2
# Iteration 637000, Current Cost: 2
# Iteration 638000, Current Cost: 2
# Iteration 639000, Current Cost: 2
# Iteration 640000, Current Cost: 2
# Iteration 641000, Current Cost: 13
# Iteration 642000, Current Cost: 4
# Iteration 643000, Current Cost: 4
# Iteration 644000, Current Cost: 4
# Iteration 645000, Current Cost: 4
# Iteration 646000, Current Cost: 4
# Iteration 647000, Current Cost: 4
# Iteration 648000, Current Cost: 4
# Iteration 649000, Current Cost: 4
# Iteration 650000, Current Cost: 4
# Iteration 651000, Current Cost: 10
# Iteration 652000, Current Cost: 8
# Iteration 653000, Current Cost: 8
# Iteration 654000, Current Cost: 6
# Iteration 655000, Current Cost: 5
# Iteration 656000, Current Cost: 4
# Iteration 657000, Current Cost: 2
# Iteration 658000, Current Cost: 2
# Iteration 659000, Current Cost: 2
# Iteration 660000, Current Cost: 2
# Iteration 661000, Current Cost: 8
# Iteration 662000, Current Cost: 4
# Best Sudoku State:
#
#  193278546
# 275614938
# 468935217
# 582347169
# 346891752
# 917526384
# 754169823
# 631782495
# 829453671
#
# Best Cost: 0
